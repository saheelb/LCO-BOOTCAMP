# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import requests as req
import io

# %%
url = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT1FENlonpBaxHAhQ1QZwmT4uJIK3kO7Mw8ZulYjC9sZU7eNgcuFA&s"
image= Image.open(io.BytesIO(req.get(url,stream=True).content)).convert("RGB")

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=205x246 at 0x254DEE54F60>

# %%
image_array=np.array(image)

# %%
image_array
# Out:
# array([[[ 24,  23,  19],
#         [ 24,  23,  19],
#         [ 24,  23,  19],
#         ...,
#         [ 22,  21,  17],
#         [ 22,  21,  17],
#         [ 22,  21,  17]],
#
#        [[ 24,  23,  19],
#         [ 24,  23,  19],
#         [ 24,  23,  19],
#         ...,
#         [ 22,  21,  17],
#         [ 22,  21,  17],
#         [ 22,  21,  17]],
#
#        [[ 24,  23,  19],
#         [ 24,  23,  19],
#         [ 24,  23,  19],
#         ...,
#         [ 22,  21,  17],
#         [ 22,  21,  17],
#         [ 22,  21,  17]],
#
#        ...,
#
#        [[152, 114, 101],
#         [152, 114, 101],
#         [153, 116, 100],
#         ...,
#         [187, 150, 131],
#         [183, 146, 127],
#         [181, 144, 125]],
#
#        [[148, 110,  97],
#         [148, 110,  97],
#         [148, 110,  97],
#         ...,
#         [189, 152, 133],
#         [185, 148, 129],
#         [183, 146, 127]],
#
#        [[146, 108,  95],
#         [146, 108,  95],
#         [146, 108,  95],
# ...

# %%
gray = cv2.cvtColor(image_array , cv2.COLOR_RGB2GRAY)
plt.imshow(gray , cmap="gray")

# %%
detector =cv2.CascadeClassifier("C:\\Users\\Saheel Bobde\\Documents\\LCO Machine_Learning\\Day 19\\xml\\haarcascades.xml")

# %%
faces = detector.detectMultiScale(gray , 1.3 ,5)

# %%
faces
# Out:
# array([[ 42,  81, 129, 129]], dtype=int32)

# %%
for face in faces:
    x,y,h,w = face
    cv2.rectangle(gray, (x,y), (x+w, y+h), (255,0,0), 5)
    cv2.imshow(gray)
    
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-08f149211d1f> in <module>
#       2     x,y,h,w = face
#       3     cv2.rectangle(gray, (x,y), (x+w, y+h), (255,0,0), 5)
# ----> 4     cv2.imshow(gray)
#       5
#       6 cap.release()
#
# TypeError: imshow() missing required argument 'mat' (pos 2)
