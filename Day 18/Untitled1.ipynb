# %%
import matplotlib.pyplot as mat
import cv2
import numpy as np

# %%
img = cv2.imread("27095.jpg", 1)
img_plot = mat.imshow(img)
shape = img.shape
def function():
    num_cols = int(input("Enter the col : "))
    num_rows = int(input("Enter the row : "))
    border = int(input("Enter border : " ))
    
    for i in range(num_cols):
        for j in range(num_rows):
            if i < border or i >= (num_cols - border):
                img[i][j] = 255
            elif i > border and j < border or i > border and j >= (num_rows - border):
                img[i][j] = 255       .
function()

# %%
mat.imshow(img)

# %% [markdown]
# for i in range(417):
#     for j in range(626):
#         if i < 10 or i >= (417 - 10):
#             greay[i][j] = 255
#         elif i > 10 and j < 10 or i > 10 and j >= (626 - 10):
#             greay[i][j] = 255

# %%
img.shape
# Out:
# (1050, 1680, 3)

# %%
def function():
    num_cols = int(input("Enter the col : "))
    num_rows = int(input("Enter the row : "))
    border = int(input("Enter border : " ))
    
    for i in range(num_cols):
        for j in range(num_rows):
            if i < border or i >= (num_cols - border):
                img[i][j] = 255
            elif i > border and j < border or i > border and j >= (num_rows - border):
                img[i][j] = 255
                
                
function()
# Out:
# Enter the col : 1050
# Enter the row : 1680
# Enter border : 30

# %%
mat.imshow(img)

# %%
def
# Out:
# True
