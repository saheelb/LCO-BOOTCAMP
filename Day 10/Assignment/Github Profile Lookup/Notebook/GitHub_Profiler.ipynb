# %%
import requests as rq
import json

# %%
class Github_Profiler:
    def __init__(self):
        self.api_url = "https://api.github.com/users/"

    def profile_user(self, username):
        url = self.api_url + username

        response = rq.get(url)

        user_data = json.loads(response.text)
        status = response.status_code

        return user_data, status 
    
    def profile_repos(self, username):
        url = self.api_url + username + "/repos"

        response = rq.get(url)

        repo_data = json.loads(response.text)
        status = response.status_code

        return repo_data, status

# %%
def main():
    profiler = Github_Profiler()
    
    user = input("Enter the GitHub Username :")
    user_data, status = profiler.profile_user(user)
    # print(status)
    if status == 200:
        print("\n" + user + " Found on Github!")
        print("\n"+ "-"*15 + " Basic User Details " + "-"*15)
        print("\n   Official Name: ", user_data['name'])
        print("   ID : ", user_data['id'])
        print("   Followers : ", user_data['followers'])
        print("   Following : ", user_data['following'])
        print("   Public Repositories : ", user_data['public_repos'])

        repo_data, status = profiler.profile_repos(user)

        if status == 200:
            print("\n"+ "-"*15 +"Public Repository Details" + "-"*15)
            for i, repo in enumerate(repo_data):
                print("\n   Repository : ", i+1)

                print("\tName : ", repo['name'])
                print("\tDescription : ", repo['description'])
                print("\tLanguage : ", repo['language'])
                print("\tURL : ", repo['html_url'])
                print("\tDate Created : ", repo['created_at'])
                print("\tStars : ", repo['stargazers_count'])
                print("\tForks : ", repo['forks'])

        else:
            print("[ERROR] : Can't Fetch "+user+" repository data due to some reason!")

    else:
        print("[ERROR] : Can't Fetch "+user+" Profile data due to some reason!")

# %%
main()
# Out:
# Enter the GitHub Username :Wizardous
#
# Wizardous Found on Github!
#
# --------------- Basic User Details ---------------
#
#    Official Name:  Abhijit Gadge
#    ID :  43639158
#    Followers :  2
#    Following :  5
#    Public Repositories :  6
#
# ---------------Public Repository Details---------------
#
#    Repository :  1
# 	Name :  Digit-Recognizer
# 	Description :  Mouse drawn live Digit Recognizer using Keras CNN and cv2 canvas
# 	Language :  None
# 	URL :  https://github.com/Wizardous/Digit-Recognizer
# 	Date Created :  2019-09-28T12:16:12Z
# 	Stars :  2
# 	Forks :  0
#
#    Repository :  2
# 	Name :  House-Price-Prediction
# 	Description :  Regression Models in Sklearn for house price analysis and prediction. [Pyhton, PyQT5]
# 	Language :  Jupyter Notebook
# 	URL :  https://github.com/Wizardous/House-Price-Prediction
# 	Date Created :  2019-10-13T12:24:00Z
# 	Stars :  0
# 	Forks :  0
#
#    Repository :  3
# 	Name :  LCO-Winter-Bootcamp
# 	Description :  Machine Learning Winter Bootcamp at LearnCodeOnline, Jaipur
# 	Language :  Jupyter Notebook
# 	URL :  https://github.com/Wizardous/LCO-Winter-Bootcamp
# 	Date Created :  2019-12-29T21:13:41Z
# 	Stars :  0
# 	Forks :  0
#
#    Repository :  4
# 	Name :  Product-Inventory-Management
# 	Description :  Python 3 program to manage Product inventory using PyQT5 and SQLite3
# 	Language :  Python
# 	URL :  https://github.com/Wizardous/Product-Inventory-Management
# 	Date Created :  2019-09-27T14:28:38Z
# 	Stars :  0
# 	Forks :  0
#
#    Repository :  5
# 	Name :  Stopwatch
# 	Description :  Clock and Stopwatch in Python3 and Kivy
# 	Language :  Python
# 	URL :  https://github.com/Wizardous/Stopwatch
# 	Date Created :  2019-09-07T19:14:26Z
# 	Stars :  1
# 	Forks :  0
#
#    Repository :  6
# 	Name :  TCP-File-Transfer
# 	Description :  C++ programs to transfer a Text file from server to client using TCP
# 	Language :  C++
# 	URL :  https://github.com/Wizardous/TCP-File-Transfer
# 	Date Created :  2019-10-20T18:05:40Z
# 	Stars :  1
# 	Forks :  0
