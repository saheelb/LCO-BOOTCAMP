# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset1 = pd.read_csv("train.csv")

# %%
dataset1['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df = pd.DataFrame(dataset1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.insert(2, "Boolean_flags", True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Boolean_flags  Pclass  \
# 0            1         0           True       3
# 1            2         1           True       1
# 2            3         1           True       3
# 3            4         1           True       1
# 4            5         0           True       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
series = pd.Series()
for row in df['Survived'].iteritems():
#     print(row)
    if 1 in row:
        return True
#     else:
#         return
# Out:
#   File "<ipython-input-36-c2e9903c2c27>", line 5
#     return True
#     ^
# SyntaxError: 'return' outside function

# %%
df.head()
# Out:
#    PassengerId  Survived  Boolean_flags  Pclass  \
# 0            1         0           True       3
# 1            2         1           True       1
# 2            3         1           True       3
# 3            4         1           True       1
# 4            5         0           True       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data = pd.DataFrame({'u_id':[1,2,3,4,5],'name':['Ironman', 'captain', 'blackwidow', 'falcon', 'thor']})

# %%
data
# Out:
#    u_id        name
# 0     1     Ironman
# 1     2     captain
# 2     3  blackwidow
# 3     4      falcon
# 4     5        thor

# %%
data.merge(data ,how ='inner', on = 'name')
# Out:
#    u_id_x        name  u_id_y
# 0       1     Ironman       1
# 1       2     captain       2
# 2       3  blackwidow       3
# 3       4      falcon       4
# 4       5        thor       5

# %%
plt.plot([1,2,3,4,5], [10,20,30,40,50], 'bo', markersize=12)
plt.ylabel('Y-Axis')
plt.xlabel('X=Axis')
plt.show()

# %%
t = np.arange(0. , 5. , 0.2)
plt.plot(t,t, 'r--', t , t**2 , 'bs' , t , t**3 , 'go')
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0,50,50),
        'd':np.random.randn(50)}
data['b'] =  data['a'] + 10*np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
# print(data['d'])
# print(data['b'])
plt.scatter('a' ,'b' , c = 'c', s = 'd' , data=data)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
names = ['groupa', 'groupb', 'groupc']
values = [1,10,100]

plt.figure(figsize=(9,3))

plt.subplot(132)
plt.bar(names, values)
plt.subplot(133)
plt.scatter(names , values)
plt.subplot(131)
plt.plot(names , values)
plt.suptitle('Categorical Plotting')
plt.show()
